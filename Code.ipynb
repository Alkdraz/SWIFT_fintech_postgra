# %%
import base64
import hashlib
import hmac
import json
import os
import time
import re
import requests

# %%
# %load 音频转文字.py



lfasr_host = 'http://raasr.xfyun.cn/api'

# 请求的接口名
api_prepare = '/prepare'
api_upload = '/upload'
api_merge = '/merge'
api_get_progress = '/getProgress'
api_get_result = '/getResult'
# 文件分片大小10M
file_piece_sice = 10485760

# ——————————————————转写可配置参数————————————————
# 参数可在官网界面（https://doc.xfyun.cn/rest_api/%E8%AF%AD%E9%9F%B3%E8%BD%AC%E5%86%99.html）查看，根据需求可自行在gene_params方法里添加修改
# 转写类型
lfasr_type = 0
# 是否开启分词
has_participle = 'false'
has_seperate = 'true'
# 多候选词个数
max_alternatives = 0
# 子用户标识
suid = ''


class SliceIdGenerator:
    """slice id生成器"""

    def __init__(self):
        self.__ch = 'aaaaaaaaa`'

    def getNextSliceId(self):
        ch = self.__ch
        j = len(ch) - 1
        while j >= 0:
            cj = ch[j]
            if cj != 'z':
                ch = ch[:j] + chr(ord(cj) + 1) + ch[j + 1:]
                break
            else:
                ch = ch[:j] + 'a' + ch[j + 1:]
                j = j - 1
        self.__ch = ch
        return self.__ch


class RequestApi(object):
    def __init__(self, appid, secret_key, upload_file_path):
        self.appid = appid
        self.secret_key = secret_key
        self.upload_file_path = upload_file_path

    # 根据不同的apiname生成不同的参数,本示例中未使用全部参数您可在官网(https://doc.xfyun.cn/rest_api/%E8%AF%AD%E9%9F%B3%E8%BD%AC%E5%86%99.html)查看后选择适合业务场景的进行更换
    def gene_params(self, apiname, taskid=None, slice_id=None):
        appid = self.appid
        secret_key = self.secret_key
        upload_file_path = self.upload_file_path
        ts = str(int(time.time()))
        m2 = hashlib.md5()
        m2.update((appid + ts).encode('utf-8'))
        md5 = m2.hexdigest()
        md5 = bytes(md5, encoding='utf-8')
        # 以secret_key为key, 上面的md5为msg， 使用hashlib.sha1加密结果为signa
        signa = hmac.new(secret_key.encode('utf-8'), md5, hashlib.sha1).digest()
        signa = base64.b64encode(signa)
        signa = str(signa, 'utf-8')
        file_len = os.path.getsize(upload_file_path)
        file_name = os.path.basename(upload_file_path)
        param_dict = {}

        if apiname == api_prepare:
            # slice_num是指分片数量，如果您使用的音频都是较短音频也可以不分片，直接将slice_num指定为1即可
            slice_num = int(file_len / file_piece_sice) + (0 if (file_len % file_piece_sice == 0) else 1)
            param_dict['app_id'] = appid
            param_dict['signa'] = signa
            param_dict['ts'] = ts
            param_dict['file_len'] = str(file_len)
            param_dict['file_name'] = file_name
            param_dict['slice_num'] = str(slice_num)
        elif apiname == api_upload:
            param_dict['app_id'] = appid
            param_dict['signa'] = signa
            param_dict['ts'] = ts
            param_dict['task_id'] = taskid
            param_dict['slice_id'] = slice_id
        elif apiname == api_merge:
            param_dict['app_id'] = appid
            param_dict['signa'] = signa
            param_dict['ts'] = ts
            param_dict['task_id'] = taskid
            param_dict['file_name'] = file_name
        elif apiname == api_get_progress or apiname == api_get_result:
            param_dict['app_id'] = appid
            param_dict['signa'] = signa
            param_dict['ts'] = ts
            param_dict['task_id'] = taskid
        return param_dict

    # 请求和结果解析，结果中各个字段的含义可参考：https://doc.xfyun.cn/rest_api/%E8%AF%AD%E9%9F%B3%E8%BD%AC%E5%86%99.html
    def gene_request(self, apiname, data, files=None, headers=None):
        print(data)
        response = requests.post(lfasr_host + apiname, data=data, files=files, headers=headers)
        result = json.loads(response.text)
        if result["ok"] == 0:
            if apiname=='/getResult':
                # 原始代码
                """
                results=re.findall(r"\"onebest\":\"(.+?)\",", result['data'])
                print(results)
                upload_file_path = self.upload_file_path
                with open(str(upload_file_path)+".txt", "a", encoding='utf-8') as f:
                    for i in results:
                        f.write(i)
                """
                data_read = result['data']
                # print(data_read)
                # 先保存整段的不做时间分隔的文本文件
                f_pure = open("录音文本(成段不分隔).txt", "a", encoding='utf-8')
                results=re.findall(r"\"onebest\":\"(.+?)\",", data_read)
                for i in results:
                    f_pure.write(i)
                f_pure.close()
                # 保存做了时间分隔的文本文件
                # 记录前一段的开始点和结束点
                record_list = json.loads(data_read)
                begin = int(record_list[0]['bg'])
                end = begin
                text = ""
                f_split = open("录音文本(带时间分隔).txt", "a", encoding='utf-8')
                for record in record_list:
                    bg = int(record['bg'])
                    ed = int(record['ed'])
                    speaker = "说话者" + record['speaker']
                    # 如果当前段的起始点和前一段的结束点重合，则合并文本
                    if bg == end:
                        text += record['onebest']
                    # 如果不重合，把缓冲区里的文本写入，然后更新上一段的起始点
                    else:
                        begin_format = self.ms_to_hours(begin)
                        end_format = self.ms_to_hours(end)
                        content = begin_format + "--" + end_format + "  " + speaker + "\n" + text + "\n\n"
                        f_split.write(content)
                        text = record['onebest']
                        begin = bg
                    # 结束点无论是否重合都得更新
                    end = ed
                # 最后一段缓冲区的文本得写入
                begin_format = self.ms_to_hours(begin)
                end_format = self.ms_to_hours(end)
                content = begin_format + "--" + end_format + "  " + speaker + "\n" + text + "\n\n"
                f_split.write(content)
                f_split.close()
            print("{} success:".format(apiname) + str(result))
            return result
        else:
            print("{} error:".format(apiname) + str(result))
            exit(0)
            return result

    # 毫秒转化为时分秒
    def ms_to_hours(self, millis):
        seconds, milliseconds = divmod(millis, 1000)
        minutes, seconds = divmod(seconds, 60)
        hours, minutes = divmod(minutes, 60)
        hours, minutes, seconds = str(hours).zfill(2), str(minutes).zfill(2), str(seconds).zfill(2)
        return "{}:{}:{}".format(hours, minutes, seconds)

    # 预处理
    def prepare_request(self):
        return self.gene_request(apiname=api_prepare,
                                 data=self.gene_params(api_prepare))

    # 上传
    def upload_request(self, taskid, upload_file_path):
        file_object = open(upload_file_path, 'rb')
        try:
            index = 1
            sig = SliceIdGenerator()
            while True:
                content = file_object.read(file_piece_sice)
                if not content or len(content) == 0:
                    break
                files = {
                    "filename": self.gene_params(api_upload).get("slice_id"),
                    "content": content
                }
                response = self.gene_request(api_upload,
                                             data=self.gene_params(api_upload, taskid=taskid,
                                                                   slice_id=sig.getNextSliceId()),
                                             files=files)
                if response.get('ok') != 0:
                    # 上传分片失败
                    print('upload slice fail, response: ' + str(response))
                    return False
                print('upload slice ' + str(index) + ' success')
                index += 1
        finally:
            'file index:' + str(file_object.tell())
            file_object.close()
        return True

    # 合并
    def merge_request(self, taskid):
        return self.gene_request(api_merge, data=self.gene_params(api_merge, taskid=taskid))

    # 获取进度
    def get_progress_request(self, taskid):
        return self.gene_request(api_get_progress, data=self.gene_params(api_get_progress, taskid=taskid))

    # 获取结果
    def get_result_request(self, taskid):
        return self.gene_request(api_get_result, data=self.gene_params(api_get_result, taskid=taskid))

    def all_api_request(self):
        # 1. 预处理
        pre_result = self.prepare_request()
        taskid = pre_result["data"]
        # 2 . 分片上传
        self.upload_request(taskid=taskid, upload_file_path=self.upload_file_path)
        # 3 . 文件合并
        self.merge_request(taskid=taskid)
        # 4 . 获取任务进度
        while True:
            # 每隔20秒获取一次任务进度
            progress = self.get_progress_request(taskid)
            progress_dic = progress
            if progress_dic['err_no'] != 0 and progress_dic['err_no'] != 26605:
                print('task error: ' + progress_dic['failed'])
                return
            else:
                data = progress_dic['data']
                task_status = json.loads(data)
                if task_status['status'] == 9:
                    print('task ' + taskid + ' finished')
                    break
                print('The task ' + taskid + ' is in processing, task status: ' + str(data))

            # 每次获取进度间隔20S
            time.sleep(20)
        # 5 . 获取结果
        self.get_result_request(taskid=taskid)


# 注意：如果出现requests模块报错："NoneType" object has no attribute 'read', 请尝试将requests模块更新到2.20.0或以上版本(本demo测试版本为2.20.0)
# 输入讯飞开放平台的appid，secret_key和待转写的音频文件路径
if __name__ == '__main__':
    # 修改此处，填上自己的app id，密钥和录音文件路径
    api = RequestApi(appid="d9f0229b", secret_key="6e263feaabe15ee6ebbdb28315cfb994", upload_file_path=r"C:\\Users\Administrator\\Thesis Programming\\音频转文字\\wav_file\\tsla_q_4_2021_01_27_earnings_summary.wav")
    api.all_api_request()
# Out:
# {'app_id': 'd9f0229b', 'signa': 'zzZiYbn5PoCAMF/nna21m4RrqpQ=', 'ts': '1668701406', 'file_len': '80600910', 'file_name': 'tsla_q_4_2021_01_27_earnings_summary.wav', 'slice_num': '8'}
# /prepare success:{'data': '1f4acf0550e244fe9c620447fd5b26a7', 'err_no': 0, 'failed': None, 'ok': 0}
# {'app_id': 'd9f0229b', 'signa': 'zzZiYbn5PoCAMF/nna21m4RrqpQ=', 'ts': '1668701406', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaaa'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 1 success
# {'app_id': 'd9f0229b', 'signa': 'tkA84yGSxdHlZXYiRygo7/OXF0M=', 'ts': '1668701408', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaab'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 2 success
# {'app_id': 'd9f0229b', 'signa': 'qrtXBFXfJdqoP1tpZQF2Siqb0I8=', 'ts': '1668701410', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaac'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 3 success
# {'app_id': 'd9f0229b', 'signa': 'mAcrBHRuJjpjYQRzLb4+rab+j/0=', 'ts': '1668701411', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaad'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 4 success
# {'app_id': 'd9f0229b', 'signa': '0qDtW35JnZooiakafDTlkgz8S5s=', 'ts': '1668701413', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaae'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 5 success
# {'app_id': 'd9f0229b', 'signa': 'uQwxdhuPut00FxbyDvfKfQo1MZg=', 'ts': '1668701415', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaaf'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 6 success
# {'app_id': 'd9f0229b', 'signa': 'l/98X30/0sUbf5/vKTvnE/K+M+4=', 'ts': '1668701417', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaag'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 7 success
# {'app_id': 'd9f0229b', 'signa': 'XLNCJHkjbZv6WrLVSmkukCE1Kcs=', 'ts': '1668701418', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'slice_id': 'aaaaaaaaah'}
# /upload success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# upload slice 8 success
# {'app_id': 'd9f0229b', 'signa': 'pg4MmGs5b4wWz0M1ImKBiuTvqoU=', 'ts': '1668701420', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7', 'file_name': 'tsla_q_4_2021_01_27_earnings_summary.wav'}
# /merge success:{'data': None, 'err_no': 0, 'failed': None, 'ok': 0}
# {'app_id': 'd9f0229b', 'signa': 'pg4MmGs5b4wWz0M1ImKBiuTvqoU=', 'ts': '1668701420', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":2,"desc":"音频合并完成"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":2,"desc":"音频合并完成"}
# {'app_id': 'd9f0229b', 'signa': 'h2Mn46tvp4w378HzgZmpAOLqWx4=', 'ts': '1668701440', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":2,"desc":"音频合并完成"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":2,"desc":"音频合并完成"}
# {'app_id': 'd9f0229b', 'signa': 'Y/QHAVNkQ114nI7kg31Dtw9PA+Y=', 'ts': '1668701460', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'HPqOHERVORSUHnrHGj+B2qrN7nk=', 'ts': '1668701480', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'rAci+TkcHWmZcFTr0DK7eAHWbkM=', 'ts': '1668701500', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'KXGjlENy+d4h+dIpzNqdeL1ABJA=', 'ts': '1668701520', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'EKjp3om1tjjvceD61RBvcOOlTbQ=', 'ts': '1668701540', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'al7U9L2mHeBlgM8sthxKsNoywtI=', 'ts': '1668701560', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'WHSvyT2Uj26phGcMD3G3yW3P1JU=', 'ts': '1668701580', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'oYwgcrTt62iN4RMOex/vpARDI0U=', 'ts': '1668701600', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'yBRABQxbH+hjYgObZNOxYeeaB3s=', 'ts': '1668701620', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'NJjVAmmoXWxyt8QpfCj0ARyfqkw=', 'ts': '1668701641', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'Trr8z062qIFhSLolf4GxViTPRRs=', 'ts': '1668701661', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'Yjaknr0xz09xi5ZLWNEQoulK4Ls=', 'ts': '1668701681', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'nr0npkN6wVJhcruWzCDZRuHQ4MM=', 'ts': '1668701701', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'rTTmVajeiI3eZ5ySZfjUeUuhPp8=', 'ts': '1668701721', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'Hw/ehlak9Nx/G5rj4aG4/B3pO5M=', 'ts': '1668701741', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': 'wMiRcxiTjBfKnjvd0AoiUGeKaYM=', 'ts': '1668701761', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":3,"desc":"音频转写中"}', 'err_no': 0, 'failed': None, 'ok': 0}
# The task 1f4acf0550e244fe9c620447fd5b26a7 is in processing, task status: {"status":3,"desc":"音频转写中"}
# {'app_id': 'd9f0229b', 'signa': '0w8OZ+wbh/unJwMIzdnHIMbamJw=', 'ts': '1668701781', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getProgress success:{'data': '{"status":9,"desc":"转写结果上传完成"}', 'err_no': 0, 'failed': None, 'ok': 0}
# task 1f4acf0550e244fe9c620447fd5b26a7 finished
# {'app_id': 'd9f0229b', 'signa': '0w8OZ+wbh/unJwMIzdnHIMbamJw=', 'ts': '1668701781', 'task_id': '1f4acf0550e244fe9c620447fd5b26a7'}
# /getResult success:{'data': '[{"bg":"0","ed":"9330","onebest":" oh Ladies and gentlemen，thank you for standing by and welcome to tesla q 42,020 financial results in q and a web cast。","speaker":"0"},{"bg":"9400","ed":"15860","onebest":"At this time our participants are in a listen only mode after the speaker presentation there will be a question and answer session。","speaker":"0"},{"bg":"15860","ed":"22880","onebest":"To ask a question during the session you will need to press star one on your telephone。Please be advised that today\'s conference is being recorded。","speaker":"0"},{"bg":"22890","ed":"30940","onebest":"If you require any further assistance，please press star zero。I would now is to hand the conference over to your speaker mister martin vehicle，","speaker":"0"},{"bg":"30940","ed":"34990","onebest":"senior director of investor relations。Please go ahead，sir。","speaker":"0"},{"bg":"35750","ed":"37710","onebest":"Thank you，sherry and good afternoon，everyone。","speaker":"0"},{"bg":"37710","ed":"41290","onebest":"And welcome to test bus 4th quarter，2020q and a web cast。","speaker":"0"},{"bg":"41530","ed":"46230","onebest":"I\'m joined today by elon musk，zachary kurt horn and a number of other executives。","speaker":"0"},{"bg":"46670","ed":"53960","onebest":"Our q four results were announced at about one pm pacific time in the update that we published at the same link as this web cast。","speaker":"0"},{"bg":"54360","ed":"58800","onebest":"During this call，we will discuss our business outlook and make forward looking statements。","speaker":"0"},{"bg":"58990","ed":"62790","onebest":"These comments are based on our predictions and expectations as of today。","speaker":"0"},{"bg":"62790","ed":"68080","onebest":"Actual events or results could differ materially due to a number of risks and uncertainties，","speaker":"0"},{"bg":"68160","ed":"71540","onebest":"including those mentioned in our most recent filings with the fcc","speaker":"0"},{"bg":"71930","ed":"77430","onebest":" during the question and answer portion of today\'s call，please limit yourself to one question and one follow up。","speaker":"0"},{"bg":"77450","ed":"79130","onebest":"uh Please press star one。","speaker":"0"},{"bg":"79130","ed":"81810","onebest":"Now，if you like to join the question queue。","speaker":"0"},{"bg":"81850","ed":"85420","onebest":"But before we jump into q and a elon has some opening remarks。","speaker":"0"},{"bg":"85420","ed":"86080","onebest":"Go on。","speaker":"0"},{"bg":"86270","ed":"87800","onebest":"啊再见。","speaker":"0"},{"bg":"88030","ed":"90020","onebest":"so Just to recap the year，","speaker":"0"},{"bg":"90060","ed":"93600","onebest":"uh2020 was the defining gear for us on many levels。","speaker":"0"},{"bg":"94070","ed":"99600","onebest":"Despite a challenging environment，we reached an important milestone of producing and delivering half 1 million cars。","speaker":"0"},{"bg":"99600","ed":"100830","onebest":"um I just like the","speaker":"0"},{"bg":"101830","ed":"105140","onebest":" once again，thanks the people of tesla for incredible effort。","speaker":"0"},{"bg":"105290","ed":"106750","onebest":"uh we We delivered","speaker":"0"},{"bg":"106920","ed":"108900","onebest":" uh almost raised many cars。","speaker":"0"},{"bg":"109110","ed":"111710","onebest":"Last year as we produced in our entire history。","speaker":"0"},{"bg":"111710","ed":"114500","onebest":"uh So really uh incredible","speaker":"0"},{"bg":"114500","ed":"115670","onebest":" uh growth rate。","speaker":"0"},{"bg":"115670","ed":"118330","onebest":"uh and And despite a very challenging","speaker":"0"},{"bg":"118330","ed":"119380","onebest":" by2020。","speaker":"0"},{"bg":"119490","ed":"123560","onebest":"So when when my head is up and such an artwork with such great people at","speaker":"0"},{"bg":"123680","ed":"124910","onebest":" as as well。","speaker":"0"},{"bg":"125870","ed":"126610","onebest":"So","speaker":"0"},{"bg":"126610","ed":"127330","onebest":" um","speaker":"0"},{ ...
